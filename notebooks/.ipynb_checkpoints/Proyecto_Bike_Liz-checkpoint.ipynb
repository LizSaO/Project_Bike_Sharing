# %%
pip list

# %% [markdown]
# **Librerias**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression

import pickle
# Out:
# C:\Users\Lizbeth\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# **Exploración inicial**

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
bike_sharing = fetch_ucirepo(id=275)

# data (as pandas dataframes)
X = bike_sharing.data.features
y = bike_sharing.data.targets

# %%
bike=pd.concat([X,y], axis=1)

# %%
bike.tail(5)
# Out:
#            dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 17374  2012-12-31       1   1    12  19        0        1           1
# 17375  2012-12-31       1   1    12  20        0        1           1
# 17376  2012-12-31       1   1    12  21        0        1           1
# 17377  2012-12-31       1   1    12  22        0        1           1
# 17378  2012-12-31       1   1    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  cnt
# 17374           2  0.26  0.2576  0.60     0.1642  119
# 17375           2  0.26  0.2576  0.60     0.1642   89
# 17376           1  0.26  0.2576  0.60     0.1642   90
# 17377           1  0.26  0.2727  0.56     0.1343   61
# 17378           1  0.26  0.2727  0.65     0.1343   49

# %%
bike.shape
# Out:
# (17379, 14)

# %%
bike.describe()
# Out:
#              season            yr          mnth            hr       holiday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770
# std        1.106918      0.500008      3.438776      6.914405      0.167165
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        2.000000      0.000000      4.000000      6.000000      0.000000
# 50%        3.000000      1.000000      7.000000     12.000000      0.000000
# 75%        3.000000      1.000000     10.000000     18.000000      0.000000
# max        4.000000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# std        2.005771      0.465431      0.639357      0.192556      0.171850
# min        0.000000      0.000000      1.000000      0.020000      0.000000
# 25%        1.000000      0.000000      1.000000      0.340000      0.333300
# 50%        3.000000      1.000000      1.000000      0.500000      0.484800
# 75%        5.000000      1.000000      2.000000      0.660000      0.621200
# max        6.000000      1.000000      4.000000      1.000000      1.000000
#
#                 hum     windspeed           cnt
# count  17379.000000  17379.000000  17379.000000
# mean       0.627229      0.190098    189.463088
# std        0.192930      0.122340    181.387599
# min        0.000000      0.000000      1.000000
# 25%        0.480000      0.104500     40.000000
# 50%        0.630000      0.194000    142.000000
# 75%        0.780000      0.253700    281.000000
# max        1.000000      0.850700    977.000000

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      17379 non-null  object
#  1   season      17379 non-null  int64
#  2   yr          17379 non-null  int64
#  3   mnth        17379 non-null  int64
#  4   hr          17379 non-null  int64
#  5   holiday     17379 non-null  int64
#  6   weekday     17379 non-null  int64
#  7   workingday  17379 non-null  int64
#  8   weathersit  17379 non-null  int64
#  9   temp        17379 non-null  float64
#  10  atemp       17379 non-null  float64
#  11  hum         17379 non-null  float64
#  12  windspeed   17379 non-null  float64
#  13  cnt         17379 non-null  int64
# dtypes: float64(4), int64(9), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# Calidad de los datos

# %%
#Porcentaje de Nulos
round(100*(bike.isnull().sum()/len(bike)), 2).sort_values(ascending=False)
# Out:
# dteday        0.0
# season        0.0
# yr            0.0
# mnth          0.0
# hr            0.0
# holiday       0.0
# weekday       0.0
# workingday    0.0
# weathersit    0.0
# temp          0.0
# atemp         0.0
# hum           0.0
# windspeed     0.0
# cnt           0.0
# dtype: float64

# %%
#Duplicados
bike_dup = bike.copy()
bike_dup.drop_duplicates(subset=None, inplace=True)
bike_dup.shape
# Out:
# (17379, 14)

# %% [markdown]
# **Pre-ingenieria**

# %%
bike.columns
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt'],
#       dtype='object')

# %%
bike['dteday']=pd.to_datetime(bike['dteday'],format="%Y-%m-%d")

# %% [markdown]
# Nueva variable número de semana del año

# %%
bike['week_number'] = bike['dteday'].dt.isocalendar().week

# %%
Varc=[ 'temp', 'atemp', 'hum', 'windspeed']
Vard=['season','mnth','weekday','weathersit','hr']
Varf=['dteday','week_number']
Varb=['yr','holiday','workingday']
Varo=['cnt']

# %% [markdown]
# Data frame sin la fecha

# %%
bike_new=bike[['season', 'yr', 'hr','mnth', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
       'cnt']]

# %% [markdown]
# Dumies

# %%
#bike['cnt'].plot(kind='hist', bins=20, title='cnt')
#plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
for variable in Vard:
    bike_new[variable] = bike_new[variable].astype('category')
# Out:
# <ipython-input-17-282f66aabc4d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike_new[variable] = bike_new[variable].astype('category')

# %%
bike_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      17379 non-null  category
#  1   yr          17379 non-null  int64
#  2   hr          17379 non-null  category
#  3   mnth        17379 non-null  category
#  4   holiday     17379 non-null  int64
#  5   weekday     17379 non-null  category
#  6   workingday  17379 non-null  int64
#  7   weathersit  17379 non-null  category
#  8   temp        17379 non-null  float64
#  9   atemp       17379 non-null  float64
#  10  hum         17379 non-null  float64
#  11  windspeed   17379 non-null  float64
#  12  cnt         17379 non-null  int64
# dtypes: category(5), float64(4), int64(4)
# memory usage: 1.1 MB

# %%
#Creación de dumies
bike_new = pd.get_dummies(bike_new, drop_first=True)

# %%
bike_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 54 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            17379 non-null  int64
#  1   holiday       17379 non-null  int64
#  2   workingday    17379 non-null  int64
#  3   temp          17379 non-null  float64
#  4   atemp         17379 non-null  float64
#  5   hum           17379 non-null  float64
#  6   windspeed     17379 non-null  float64
#  7   cnt           17379 non-null  int64
#  8   season_2      17379 non-null  bool
#  9   season_3      17379 non-null  bool
#  10  season_4      17379 non-null  bool
#  11  hr_1          17379 non-null  bool
#  12  hr_2          17379 non-null  bool
#  13  hr_3          17379 non-null  bool
#  14  hr_4          17379 non-null  bool
#  15  hr_5          17379 non-null  bool
#  16  hr_6          17379 non-null  bool
#  17  hr_7          17379 non-null  bool
#  18  hr_8          17379 non-null  bool
#  19  hr_9          17379 non-null  bool
#  20  hr_10         17379 non-null  bool
#  21  hr_11         17379 non-null  bool
#  22  hr_12         17379 non-null  bool
#  23  hr_13         17379 non-null  bool
#  24  hr_14         17379 non-null  bool
#  25  hr_15         17379 non-null  bool
#  26  hr_16         17379 non-null  bool
#  27  hr_17         17379 non-null  bool
#  28  hr_18         17379 non-null  bool
#  29  hr_19         17379 non-null  bool
#  30  hr_20         17379 non-null  bool
#  31  hr_21         17379 non-null  bool
#  32  hr_22         17379 non-null  bool
#  33  hr_23         17379 non-null  bool
#  34  mnth_2        17379 non-null  bool
#  35  mnth_3        17379 non-null  bool
#  36  mnth_4        17379 non-null  bool
#  37  mnth_5        17379 non-null  bool
#  38  mnth_6        17379 non-null  bool
#  39  mnth_7        17379 non-null  bool
#  40  mnth_8        17379 non-null  bool
#  41  mnth_9        17379 non-null  bool
#  42  mnth_10       17379 non-null  bool
#  43  mnth_11       17379 non-null  bool
#  44  mnth_12       17379 non-null  bool
#  45  weekday_1     17379 non-null  bool
#  46  weekday_2     17379 non-null  bool
#  47  weekday_3     17379 non-null  bool
#  48  weekday_4     17379 non-null  bool
#  49  weekday_5     17379 non-null  bool
#  50  weekday_6     17379 non-null  bool
#  51  weathersit_2  17379 non-null  bool
#  52  weathersit_3  17379 non-null  bool
#  53  weathersit_4  17379 non-null  bool
# dtypes: bool(46), float64(4), int64(4)
# memory usage: 1.8 MB

# %%
bike_new.shape
# Out:
# (17379, 54)

# %% [markdown]
# Variables continuas

# %%
bike[Varc+Varo].hist(figsize=(4,4))
# Out:
# array([[<Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>],
#        [<Axes: title={'center': 'hum'}>,
#         <Axes: title={'center': 'windspeed'}>],
#        [<Axes: title={'center': 'cnt'}>, <Axes: >]], dtype=object)

# %%
sns.pairplot(bike[Varc], diag_kind='kde')
plt.show()

# %%
sns.pairplot(bike,x_vars=Varc, y_vars=Varo)
plt.show()

# %% [markdown]
# Variables discretas

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25, 10))
for i, col in enumerate(Vard):
    plt.subplot(2,3,i+1)
    sns.boxplot(x = col, y = 'cnt', data = bike)
plt.show()

# %%
plt.figure(figsize = (25,20))
sns.heatmap(bike_new.corr(), annot = True, cmap="RdBu")
plt.show()

# %% [markdown]
# **Escalar las varibles continuas**

# %%
scaler = MinMaxScaler()

# %%
bike_new.head()
# Out:
#    yr  holiday  workingday  temp   atemp   hum  windspeed  cnt  season_2  \
# 0   0        0           0  0.24  0.2879  0.81        0.0   16     False
# 1   0        0           0  0.22  0.2727  0.80        0.0   40     False
# 2   0        0           0  0.22  0.2727  0.80        0.0   32     False
# 3   0        0           0  0.24  0.2879  0.75        0.0   13     False
# 4   0        0           0  0.24  0.2879  0.75        0.0    1     False
#
#    season_3  ...  mnth_12  weekday_1  weekday_2  weekday_3  weekday_4  \
# 0     False  ...    False      False      False      False      False
# 1     False  ...    False      False      False      False      False
# 2     False  ...    False      False      False      False      False
# 3     False  ...    False      False      False      False      False
# 4     False  ...    False      False      False      False      False
#
#    weekday_5  weekday_6  weathersit_2  weathersit_3  weathersit_4
# 0      False       True         False         False         False
# 1      False       True         False         False         False
# 2      False       True         False         False         False
# 3      False       True         False         False         False
# 4      False       True         False         False         False
#
# [5 rows x 54 columns]

# %%
bike_new[Varc+Varo] = scaler.fit_transform(bike_new[Varc+Varo])

# %%
bike_new.head()
# Out:
#    yr  holiday  workingday      temp   atemp   hum  windspeed       cnt  \
# 0   0        0           0  0.224490  0.2879  0.81        0.0  0.015369
# 1   0        0           0  0.204082  0.2727  0.80        0.0  0.039959
# 2   0        0           0  0.204082  0.2727  0.80        0.0  0.031762
# 3   0        0           0  0.224490  0.2879  0.75        0.0  0.012295
# 4   0        0           0  0.224490  0.2879  0.75        0.0  0.000000
#
#    season_2  season_3  ...  mnth_12  weekday_1  weekday_2  weekday_3  \
# 0     False     False  ...    False      False      False      False
# 1     False     False  ...    False      False      False      False
# 2     False     False  ...    False      False      False      False
# 3     False     False  ...    False      False      False      False
# 4     False     False  ...    False      False      False      False
#
#    weekday_4  weekday_5  weekday_6  weathersit_2  weathersit_3  weathersit_4
# 0      False      False       True         False         False         False
# 1      False      False       True         False         False         False
# 2      False      False       True         False         False         False
# 3      False      False       True         False         False         False
# 4      False      False       True         False         False         False
#
# [5 rows x 54 columns]

# %%
bike_new.describe()
# Out:
#                  yr       holiday    workingday          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.502561      0.028770      0.682721      0.486722      0.475775
# std        0.500008      0.167165      0.465431      0.196486      0.171850
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.326531      0.333300
# 50%        1.000000      0.000000      1.000000      0.489796      0.484800
# 75%        1.000000      0.000000      1.000000      0.653061      0.621200
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                 hum     windspeed           cnt
# count  17379.000000  17379.000000  17379.000000
# mean       0.627229      0.223460      0.193097
# std        0.192930      0.143811      0.185848
# min        0.000000      0.000000      0.000000
# 25%        0.480000      0.122840      0.039959
# 50%        0.630000      0.228047      0.144467
# 75%        0.780000      0.298225      0.286885
# max        1.000000      1.000000      1.000000

# %% [markdown]
# **Modelado**

# %%
np.random.seed(0)
bike_train, bike_test = train_test_split(bike_new, train_size = 0.80, test_size = 0.20, random_state = 42)

# %%
bike_test.shape
# Out:
# (3476, 54)

# %%
bike_train.shape
# Out:
# (13903, 54)

# %%
y_train = bike_train.pop('cnt')
X_train = bike_train

y_test = bike_test.pop('cnt')
X_test = bike_test

# %% [markdown]
# Seleccionaremos a las mejores 25 variables

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(estimator=lm,n_features_to_select=25)             # running RFE
rfe = rfe.fit(X_train, y_train)

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'holiday', 'workingday', 'atemp', 'hr_7', 'hr_8', 'hr_9', 'hr_10',
#        'hr_11', 'hr_12', 'hr_13', 'hr_14', 'hr_15', 'hr_16', 'hr_17', 'hr_18',
#        'hr_19', 'hr_20', 'hr_21', 'weekday_1', 'weekday_2', 'weekday_3',
#        'weekday_4', 'weekday_5', 'weathersit_4'],
#       dtype='object')

# %%
#list(zip(X_train.columns,rfe.support_,rfe.ranking_))

# %%
# Modelo de regresion lineal
X_train_rfe = X_train[col]
X_test_rfe = X_test[col]

modelo= LinearRegression()
modelo.fit(X_train_rfe, y_train)
# Out:
# LinearRegression()

# %%
#Validar con el conjunto de test
y_pred = modelo.predict(X_test_rfe)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MSE:', mse)
print('R2:', r2)
# Out:
# MSE: 0.012389079740078933
# R2: 0.6273050143865275

# %% [markdown]
# Modelo final

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline(steps=[('scaler', MinMaxScaler()),
                   ('rfe', RFE(estimator=LinearRegression(),n_features_to_select=25)),
                   ('modelo', LinearRegression())])
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('MSE:', mse)
print('R2:', r2)

# %% [markdown]
# Pipeline Final

# %%
with open('trained_model-1.0.0.pkl','wb') as f:
  pickle.dump(pipe, f)

# %%
with open('trained_model-1.0.0.pkl', 'rb') as f:
  model = pickle.load(f)

# %%
#defición de la función
def predict_cnt(data):

   data_df = pd.DataFrame(data, index=[0])
   for variable in Vard:
    data_df[variable] = data_df[variable].astype('category')
   print("Listo catgoricas")

   data_df = pd.get_dummies(data_df, drop_first=True)
   print("Listo dummies")
   print(data_df.info)

   data_df[Varc] = scaler.fit_transform(data_df[Varc])
   print("Listo escalar")

   prediction = model.predict(data_df)[0]

   return prediction

# %%
# Validar

data = {'season': 1, 'yr': 1, 'hr': 10, 'mnth': 1, 'holiday': 0, 'weekday': 1,
       'workingday': 1, 'weathersit': 1, 'temp': 0.344146, 'atemp': 0.363628,
       'hum': 0.805825, 'windspeed': 0.160446}

prediction = predict_cnt(data)
print(f"Predicted number of bike rentals: {prediction}")
# Out:
# Listo catgoricas
# Listo dummies
# <bound method DataFrame.info of    yr  holiday  workingday      temp     atemp       hum  windspeed
# 0   1        0           1  0.344146  0.363628  0.805825   0.160446>
# Listo escalar
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-0020d1a8f3f3> in <cell line: 7>()
#       5        'hum': 0.805825, 'windspeed': 0.160446}
#       6
# ----> 7 prediction = predict_cnt(data)
#       8 print(f"Predicted number of bike rentals: {prediction}")
#
# <ipython-input-71-a1150eea7cb3> in predict_cnt(data)
#      14    print("Listo escalar")
#      15
# ---> 16    prediction = model.predict(data_df)[0]
#      17
#      18    return prediction
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     478         Xt = X
#     479         for _, name, transform in self._iter(with_final=False):
# --> 480             Xt = transform.transform(Xt)
#     481         return self.steps[-1][1].predict(Xt, **predict_params)
#     482
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in transform(self, X)
#     506         check_is_fitted(self)
#     507
# --> 508         X = self._validate_data(
#     509             X,
#     510             copy=self.copy,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     546             validated.
#     547         """
# --> 548         self._check_feature_names(X, reset=reset)
#     549
#     550         if y is None and self._get_tags()["requires_y"]:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _check_feature_names(self, X, reset)
#     479                 )
#     480
# --> 481             raise ValueError(message)
#     482
#     483     def _validate_data(
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - hr_1
# - hr_10
# - hr_11
# - hr_12
# - hr_13
# - ...
